# %%
import os
import sys

# 打印当前工作目录
print("当前工作目录 (CWD):", os.getcwd())

# 打印 Python 解释器位置 (确保你在用 .venv)
print("Python 解释器:", sys.executable)
# Out:
# 当前工作目录 (CWD): /home/zihan/zhikai/vrp-benchmarks/notebook
# Python 解释器: /home/zihan/zhikai/vrp-benchmarks/.venv/bin/python

# %%
import sys
import os

# 获取当前 notebook 所在的目录
current_dir = os.getcwd()

# 如果 load_dataset.py 不在当前目录下，尝试将父目录加入 path
if not os.path.exists(os.path.join(current_dir, 'load_dataset.py')):
    parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
    if parent_dir not in sys.path:
        sys.path.append(parent_dir)

from load_dataset import load_vrp_dataset
print("成功导入 load_vrp_dataset")
# Out:
# 成功导入 load_vrp_dataset
